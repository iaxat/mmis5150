# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import json
import requests
# libraries

# %%
tf.__version__, tf.test.gpu_device_name()
# GPU version
# Out:
# ('2.5.0-dev20210314', '')

# %%
# what is json
# inbuilt python library
json.__version__
# Out:
# '2.0.9'

# %%
# json example
# json should be string
json_data = '{"name":"akshat", "age":25, "course":"mmis"}'
# print(json_data["name"]) (this does show that json acts as string)

# json to python
json_data = json.loads(json_data)
print(json_data)
print(json_data["name"])
# working as dict now
# working as 

# python to json
json_data = json.dumps(json_data)
# print(json_data["name"]) (this shows json acts as string)
print(json_data)
# Out:
# {'name': 'akshat', 'age': 25, 'course': 'mmis'}
# akshat
# {"name": "akshat", "age": 25, "course": "mmis"}

# %%
# dict vs json
# dict is: key value pair

# data type for key value pair


json.dumps(['foo', {'bar': ('baz', None, 1.0, 2)}])
# encoding

# json:
# 
json.loads('"\\"foo\\bar"')
# Out:
# '"foo\x08ar'

# %%
# python and json object

# %%
# encoding
json_dump = json.dumps([1, 2, 3, {'4': 5, '6': 7}], separators=(',', ':'))
print(json_dump)

# decoding

# %%
# types of data

# %%
# what is not supported 
# what can go wrong

# %%
# Indentation changes + format changes

# %%
# csv, text, dict, xml, change json to and from

# %%
# extract data api and store + print

# %%
# convert base 64
# pro cons
# image + sound store

# %%
# 2d array, 2d dict store json

# %%
# stock trading

# %%
# crypto

# %%
# common name data json

# %%
# language translation

# %%
# international space station api

# %%
# nasa api

# %%
# parse resume profiler

# %%
# news sentiment

# %%
# NOW MOVING TO NUMPY
np.__version__
# Out:
# '1.19.5'

# %%
#

# %%
# NOW MOVING TO PANDAS
pd.__version__
# Out:
# '1.2.3'

# %%
#
