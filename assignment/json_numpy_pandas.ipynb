# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import json
import requests
# libraries

# %%
tf.__version__, tf.test.gpu_device_name()
# GPU version
# Out:
# ('2.4.1', '/device:GPU:0')
